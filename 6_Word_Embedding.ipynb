# %% [markdown]
# # **Go through link to know more about word embedding**
# https://www.analyticsvidhya.com/blog/2021/06/part-7-step-by-step-guide-to-master-nlp-word-embedding/

# %%
## pretrained GloVe embeddings model
## check more at https://github.com/RaRe-Technologies/gensim-data

import gensim.downloader as api
model = api.load("glove-wiki-gigaword-50")

# %%
## any word vector can be accessed by pasing word like below
v_king = model['king']
v_queen = model['queen']

print("Length/Dimension of vector :" , len(v_king))
print("Length/Dimension of vector :" , len(v_queen))
print(" ")
print("vector")
print(v_king)
# Out:
# Length/Dimension of vector : 50
# Length/Dimension of vector : 50
#
# vector
# [ 0.50451   0.68607  -0.59517  -0.022801  0.60046  -0.13498  -0.08813
#   0.47377  -0.61798  -0.31012  -0.076666  1.493    -0.034189 -0.98173
#   0.68229   0.81722  -0.51874  -0.31503  -0.55809   0.66421   0.1961
#  -0.13495  -0.11476  -0.30344   0.41177  -2.223    -1.0756   -1.0783
#  -0.34354   0.33505   1.9927   -0.04234  -0.64319   0.71125   0.49159
#   0.16754   0.34344  -0.25663  -0.8523    0.1661    0.40102   1.1685
#  -1.0137   -0.21585  -0.15155   0.78321  -0.91241  -1.6106   -0.64426
#  -0.51042 ]

# %% [markdown]
# **Check Similarity of words using word vector**

# %%
## check similarity beween two words/word-vectors
print("similarity:", model.similarity('king', 'queen'))
# Out:
# similarity: 0.7839043

# %%
##most similar words to king
model.most_similar('king', topn=5)
# Out:
# [('prince', 0.8236179351806641),
#  ('queen', 0.7839042544364929),
#  ('ii', 0.7746230363845825),
#  ('emperor', 0.7736247181892395),
#  ('son', 0.766719400882721)]

# %%
w1=model['science']
w2= model['physics']
w3 = model['cricket']
w4 = model['chemistry']

model.cosine_similarities(w1, [w2, w3, w4])
# Out:
# array([0.8314354 , 0.27207178, 0.8080922 ], dtype=float32)

# %%
## Vector operation on word vector gives correct new word vector
## e.g. King+Woman-Man = Queen
print(model.most_similar(positive=['woman', 'king'], negative=['man'], topn=3))
# Out:
# [('queen', 0.8523603677749634), ('throne', 0.7664334177970886), ('prince', 0.759214460849762)]

# %%
model.most_similar(positive=['india', 'capital'], topn=5)
# Out:
# [('indian', 0.8180676698684692),
#  ('central', 0.8107988834381104),
#  ('delhi', 0.8071692585945129),
#  ('indonesia', 0.8021898865699768),
#  ('pakistan', 0.8015152812004089)]

# %% [markdown]
# # **Training and Evaluate Your Own Embeddings**

# %%
import urllib
import re

# change to your own path if you have downloaded the file locally
url = 'https://dataskat.s3.eu-west-3.amazonaws.com/data/Shakespeare_alllines.txt'
# read file into list of lines
lines = urllib.request.urlopen(url).read().decode('utf-8').split("\n")

# %%
sentences = []
for line in lines:
    # remove punctuation
    line = re.sub(r'[\!"#$%&\*+,-./:;<=>?@^_`()|~=]','',line).strip()
    # tokenizer
    tokens = re.findall(r'\b\w+\b', line)
    if len(tokens) > 1:
        sentences.append(tokens)

# %%
sentences[0:10]
# Out:
# [['ACT', 'I'],
#  ['SCENE', 'I', 'London', 'The', 'palace'],
#  ['Enter',
#   'KING',
#   'HENRY',
#   'LORD',
#   'JOHN',
#   'OF',
#   'LANCASTER',
#   'the',
#   'EARL',
#   'of',
#   'WESTMORELAND',
#   'SIR',
#   'WALTER',
#   'BLUNT',
#   'and',
#   'others'],
#  ['So', 'shaken', 'as', 'we', 'are', 'so', 'wan', 'with', 'care'],
#  ['Find', 'we', 'a', 'time', 'for', 'frighted', 'peace', 'to', 'pant'],
#  ['And', 'breathe', 'shortwinded', 'accents', 'of', 'new', 'broils'],
#  ['To', 'be', 'commenced', 'in', 'strands', 'afar', 'remote'],
#  ['No', 'more', 'the', 'thirsty', 'entrance', 'of', 'this', 'soil'],
#  ['Shall',
#   'daub',
#   'her',
#   'lips',
#   'with',
#   'her',
#   'own',
#   'children',
#   's',
#   'blood'],
#  ['Nor', 'more', 'shall', 'trenching', 'war', 'channel', 'her', 'fields']]

# %% [markdown]
# ## **Train model using Gensim**

# %%
import logging
logging.basicConfig(format='%(asctime)s: %(levelname)s: %(message)s', level=logging.INFO)
logging.getLogger().setLevel(logging.INFO)

# %%
from gensim.models import Word2Vec

cust_model = Word2Vec(sentences,       # tokenized input sentences
                 size=100,    # size of word vectors (default 100)
                 window=2,    # context window size (default 5)
                 sg=1,        # use skip-gram (default 0 = CBOW)
                 negative=5,  # number of negative samples (default 5)
                 min_count=5, # ignore infrequent words (default 5)
                 workers=4,   # number of threads (default 3)
                 iter=5)      # number of epochs (default 5)
# Out:
# 2022-01-20 11:36:46,511: INFO: collecting all words and their counts
# 2022-01-20 11:36:46,513: INFO: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2022-01-20 11:36:46,540: INFO: PROGRESS: at sentence #10000, processed 79207 words, keeping 8710 word types
# 2022-01-20 11:36:46,563: INFO: PROGRESS: at sentence #20000, processed 156921 words, keeping 12509 word types
# 2022-01-20 11:36:46,586: INFO: PROGRESS: at sentence #30000, processed 230335 words, keeping 15538 word types
# 2022-01-20 11:36:46,609: INFO: PROGRESS: at sentence #40000, processed 306343 words, keeping 18757 word types
# 2022-01-20 11:36:46,632: INFO: PROGRESS: at sentence #50000, processed 381777 words, keeping 20753 word types
# 2022-01-20 11:36:46,655: INFO: PROGRESS: at sentence #60000, processed 455792 words, keeping 23041 word types
# 2022-01-20 11:36:46,680: INFO: PROGRESS: at sentence #70000, processed 535002 words, keeping 24926 word types
# 2022-01-20 11:36:46,704: INFO: PROGRESS: at sentence #80000, processed 610642 words, keeping 26451 word types
# 2022-01-20 11:36:46,735: INFO: PROGRESS: at sentence #90000, processed 687819 words, keeping 27905 word types
# 2022-01-20 11:36:46,761: INFO: PROGRESS: at sentence #100000, processed 763170 words, keeping 29478 word types
# 2022-01-20 11:36:46,787: INFO: collected 30675 word types from a corpus of 830015 raw words and 108774 sentences
# 2022-01-20 11:36:46,790: INFO: Loading a fresh vocabulary
# 2022-01-20 11:36:46,826: INFO: effective_min_count=5 retains 9106 unique words (29% of original 30675, drops 21569)
# 2022-01-20 11:36:46,832: INFO: effective_min_count=5 leaves 795574 word corpus (95% of original 830015, drops 34441)
# 2022-01-20 11:36:46,871: INFO: deleting the raw counts dictionary of 30675 items
# 2022-01-20 11:36:46,873: INFO: sample=0.001 downsamples 55 most-common words
# 2022-01-20 11:36:46,874: INFO: downsampling leaves estimated 619881 word corpus (77.9% of prior 795574)
# 2022-01-20 11:36:46,915: INFO: estimated required memory for 9106 words and 100 dimensions: 11837800 bytes
# 2022-01-20 11:36:46,917: INFO: resetting layer weights
# 2022-01-20 11:36:48,861: INFO: training model with 4 workers on 9106 vocabulary and 100 features, using sg=1 hs=0 sample=0.001 negative=5 window=2
# 2022-01-20 11:36:49,887: INFO: EPOCH 1 - PROGRESS: at 61.43% examples, 374468 words/s, in_qsize 7, out_qsize 3
# 2022-01-20 11:36:50,421: INFO: worker thread finished; awaiting finish of 3 more threads
# 2022-01-20 11:36:50,424: INFO: worker thread finished; awaiting finish of 2 more threads
# 2022-01-20 11:36:50,429: INFO: worker thread finished; awaiting finish of 1 more threads
# 2022-01-20 11:36:50,436: INFO: worker thread finished; awaiting finish of 0 more threads
# 2022-01-20 11:36:50,438: INFO: EPOCH - 1 : training on 830015 raw words (619612 effective words) took 1.6s, 395795 effective words/s
# 2022-01-20 11:36:51,457: INFO: EPOCH 2 - PROGRESS: at 62.62% examples, 385099 words/s, in_qsize 6, out_qsize 1
# 2022-01-20 11:36:52,004: INFO: worker thread finished; awaiting finish of 3 more threads
# 2022-01-20 11:36:52,007: INFO: worker thread finished; awaiting finish of 2 more threads
# 2022-01-20 11:36:52,011: INFO: worker thread finished; awaiting finish of 1 more threads
# 2022-01-20 11:36:52,016: INFO: worker thread finished; awaiting finish of 0 more threads
# 2022-01-20 11:36:52,017: INFO: EPOCH - 2 : training on 830015 raw words (619840 effective words) took 1.6s, 395818 effective words/s
# 2022-01-20 11:36:53,031: INFO: EPOCH 3 - PROGRESS: at 62.62% examples, 387316 words/s, in_qsize 7, out_qsize 0
# 2022-01-20 11:36:53,582: INFO: worker thread finished; awaiting finish of 3 more threads
# 2022-01-20 11:36:53,589: INFO: worker thread finished; awaiting finish of 2 more threads
# 2022-01-20 11:36:53,591: INFO: worker thread finished; awaiting finish of 1 more threads
# 2022-01-20 11:36:53,612: INFO: worker thread finished; awaiting finish of 0 more threads
# 2022-01-20 11:36:53,613: INFO: EPOCH - 3 : training on 830015 raw words (620244 effective words) took 1.6s, 391940 effective words/s
# 2022-01-20 11:36:54,641: INFO: EPOCH 4 - PROGRESS: at 61.42% examples, 374700 words/s, in_qsize 7, out_qsize 1
# 2022-01-20 11:36:55,154: INFO: worker thread finished; awaiting finish of 3 more threads
# 2022-01-20 11:36:55,167: INFO: worker thread finished; awaiting finish of 2 more threads
# 2022-01-20 11:36:55,182: INFO: worker thread finished; awaiting finish of 1 more threads
# 2022-01-20 11:36:55,191: INFO: worker thread finished; awaiting finish of 0 more threads
# 2022-01-20 11:36:55,193: INFO: EPOCH - 4 : training on 830015 raw words (619678 effective words) took 1.6s, 395792 effective words/s
# 2022-01-20 11:36:56,231: INFO: EPOCH 5 - PROGRESS: at 62.62% examples, 379529 words/s, in_qsize 7, out_qsize 0
# 2022-01-20 11:36:56,726: INFO: worker thread finished; awaiting finish of 3 more threads
# 2022-01-20 11:36:56,745: INFO: worker thread finished; awaiting finish of 2 more threads
# 2022-01-20 11:36:56,751: INFO: worker thread finished; awaiting finish of 1 more threads
# 2022-01-20 11:36:56,755: INFO: worker thread finished; awaiting finish of 0 more threads
# 2022-01-20 11:36:56,757: INFO: EPOCH - 5 : training on 830015 raw words (619966 effective words) took 1.5s, 400672 effective words/s
# 2022-01-20 11:36:56,759: INFO: training on a 4150075 raw words (3099340 effective words) took 7.9s, 392523 effective words/s

# %%
cust_model.wv.most_similar("king")
# Out:
# 2022-01-20 11:36:56,766: INFO: precomputing L2-norms of word weight vectors
# [('duke', 0.8617936372756958),
#  ('queen', 0.8092128038406372),
#  ('prince', 0.7938957214355469),
#  ('doctor', 0.7876814007759094),
#  ('Moor', 0.7867355346679688),
#  ('Jew', 0.7733607292175293),
#  ('Caesar', 0.767480194568634),
#  ('cardinal', 0.7622534036636353),
#  ('shepherd', 0.7612801790237427),
#  ('emperor', 0.7564812898635864)]

# %%
## save model
##model.save('./word2vec_custom_model.bin')

##load model
##model = Word2Vec.load('./word2vec_custom_model.bin')

# %% [markdown]
# ##**Train Word2Vec , FastText , Custom model**

# %%
from gensim.models import Word2Vec, FastText
import numpy as np

## change param grid 
param_grid = {'w2v': {'variant': ['cbow', 'sg'], 'window': [2,3 ]},
              'ft': {'variant': ['sg'], 'window': [5]},
               'cust':{'variant': ['sg'] ,'window': [2]}
              }
size = 100
models=[]
index=0
for algo, params in param_grid.items(): 

    for variant in params['variant']:
        sg = 1 if variant == 'sg' else 0
        for window in params['window']:
            index+=1
            print("")
            print(f"===>>Model : {index}, Algo : {algo} , Variant: {variant}, Window: {window}, Size: {size}") ###
            print("==========================================================================================")
            print("")
            np.random.seed(1) ### to ensure repeatability
            if algo == 'w2v':
                model = Word2Vec(sentences, size=size, window=window, sg=sg)
            elif algo=='cust':
                model = cust_model
            else:
                model = FastText(sentences, size=size, window=window, sg=sg)

            models.append(model)
# Out:
# 2022-01-20 11:36:56,829: INFO: collecting all words and their counts
# 2022-01-20 11:36:56,831: INFO: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2022-01-20 11:36:56,864: INFO: PROGRESS: at sentence #10000, processed 79207 words, keeping 8710 word types
# 2022-01-20 11:36:56,897: INFO: PROGRESS: at sentence #20000, processed 156921 words, keeping 12509 word types
# 2022-01-20 11:36:56,918: INFO: PROGRESS: at sentence #30000, processed 230335 words, keeping 15538 word types
# 2022-01-20 11:36:56,940: INFO: PROGRESS: at sentence #40000, processed 306343 words, keeping 18757 word types
# 2022-01-20 11:36:56,961: INFO: PROGRESS: at sentence #50000, processed 381777 words, keeping 20753 word types
# 2022-01-20 11:36:56,986: INFO: PROGRESS: at sentence #60000, processed 455792 words, keeping 23041 word types
# 2022-01-20 11:36:57,007: INFO: PROGRESS: at sentence #70000, processed 535002 words, keeping 24926 word types
# ===>>Model : 1, Algo : w2v , Variant: cbow, Window: 2, Size: 100
# ==========================================================================================
# 2022-01-20 11:36:57,039: INFO: PROGRESS: at sentence #80000, processed 610642 words, keeping 26451 word types
# 2022-01-20 11:36:57,068: INFO: PROGRESS: at sentence #90000, processed 687819 words, keeping 27905 word types
# 2022-01-20 11:36:57,089: INFO: PROGRESS: at sentence #100000, processed 763170 words, keeping 29478 word types
# 2022-01-20 11:36:57,113: INFO: collected 30675 word types from a corpus of 830015 raw words and 108774 sentences
# 2022-01-20 11:36:57,115: INFO: Loading a fresh vocabulary
# 2022-01-20 11:36:57,156: INFO: effective_min_count=5 retains 9106 unique words (29% of original 30675, drops 21569)
# 2022-01-20 11:36:57,157: INFO: effective_min_count=5 leaves 795574 word corpus (95% of original 830015, drops 34441)
# 2022-01-20 11:36:57,193: INFO: deleting the raw counts dictionary of 30675 items
# 2022-01-20 11:36:57,196: INFO: sample=0.001 downsamples 55 most-common words
# 2022-01-20 11:36:57,198: INFO: downsampling leaves estimated 619881 word corpus (77.9% of prior 795574)
# 2022-01-20 11:36:57,228: INFO: estimated required memory for 9106 words and 100 dimensions: 11837800 bytes
# 2022-01-20 11:36:57,230: INFO: resetting layer weights
# 2022-01-20 11:36:59,165: INFO: training model with 3 workers on 9106 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=2
# 2022-01-20 11:37:00,113: INFO: worker thread finished; awaiting finish of 2 more threads
# 2022-01-20 11:37:00,116: INFO: worker thread finished; awaiting finish of 1 more threads
# 2022-01-20 11:37:00,117: INFO: worker thread finished; awaiting finish of 0 more threads
# 2022-01-20 11:37:00,127: INFO: EPOCH - 1 : training on 830015 raw words (620050 effective words) took 1.0s, 650924 effective words/s
# 2022-01-20 11:37:01,070: INFO: worker thread finished; awaiting finish of 2 more threads
# 2022-01-20 11:37:01,085: INFO: worker thread finished; awaiting finish of 1 more threads
# 2022-01-20 11:37:01,093: INFO: worker thread finished; awaiting finish of 0 more threads
# 2022-01-20 11:37:01,094: INFO: EPOCH - 2 : training on 830015 raw words (619514 effective words) took 1.0s, 648379 effective words/s
# 2022-01-20 11:37:02,062: INFO: worker thread finished; awaiting finish of 2 more threads
# 2022-01-20 11:37:02,064: INFO: worker thread finished; awaiting finish of 1 more threads
# 2022-01-20 11:37:02,077: INFO: worker thread finished; awaiting finish of 0 more threads
# 2022-01-20 11:37:02,079: INFO: EPOCH - 3 : training on 830015 raw words (620094 effective words) took 1.0s, 637619 effective words/s
# 2022-01-20 11:37:03,042: INFO: worker thread finished; awaiting finish of 2 more threads
# 2022-01-20 11:37:03,057: INFO: worker thread finished; awaiting finish of 1 more threads
# 2022-01-20 11:37:03,063: INFO: worker thread finished; awaiting finish of 0 more threads
# 2022-01-20 11:37:03,064: INFO: EPOCH - 4 : training on 830015 raw words (619839 effective words) took 1.0s, 636211 effective words/s
# 2022-01-20 11:37:04,014: INFO: worker thread finished; awaiting finish of 2 more threads
# 2022-01-20 11:37:04,017: INFO: worker thread finished; awaiting finish of 1 more threads
# 2022-01-20 11:37:04,028: INFO: worker thread finished; awaiting finish of 0 more threads
# 2022-01-20 11:37:04,030: INFO: EPOCH - 5 : training on 830015 raw words (619854 effective words) took 1.0s, 650479 effective words/s
# 2022-01-20 11:37:04,031: INFO: training on a 4150075 raw words (3099351 effective words) took 4.9s, 637197 effective words/s
# 2022-01-20 11:37:04,033: INFO: collecting all words and their counts
# 2022-01-20 11:37:04,035: INFO: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2022-01-20 11:37:04,062: INFO: PROGRESS: at sentence #10000, processed 79207 words, keeping 8710 word types
# 2022-01-20 11:37:04,081: INFO: PROGRESS: at sentence #20000, processed 156921 words, keeping 12509 word types
# 2022-01-20 11:37:04,104: INFO: PROGRESS: at sentence #30000, processed 230335 words, keeping 15538 word types
# 2022-01-20 11:37:04,173: INFO: PROGRESS: at sentence #40000, processed 306343 words, keeping 18757 word types
# 2022-01-20 11:37:04,193: INFO: PROGRESS: at sentence #50000, processed 381777 words, keeping 20753 word types
# 2022-01-20 11:37:04,217: INFO: PROGRESS: at sentence #60000, processed 455792 words, keeping 23041 word types
# 2022-01-20 11:37:04,241: INFO: PROGRESS: at sentence #70000, processed 535002 words, keeping 24926 word types
# ===>>Model : 2, Algo : w2v , Variant: cbow, Window: 3, Size: 100
# ==========================================================================================
# 2022-01-20 11:37:04,269: INFO: PROGRESS: at sentence #80000, processed 610642 words, keeping 26451 word types
# 2022-01-20 11:37:04,292: INFO: PROGRESS: at sentence #90000, processed 687819 words, keeping 27905 word types
# 2022-01-20 11:37:04,334: INFO: PROGRESS: at sentence #100000, processed 763170 words, keeping 29478 word types
# 2022-01-20 11:37:04,359: INFO: collected 30675 word types from a corpus of 830015 raw words and 108774 sentences
# 2022-01-20 11:37:04,361: INFO: Loading a fresh vocabulary
# 2022-01-20 11:37:04,392: INFO: effective_min_count=5 retains 9106 unique words (29% of original 30675, drops 21569)
# 2022-01-20 11:37:04,394: INFO: effective_min_count=5 leaves 795574 word corpus (95% of original 830015, drops 34441)
# 2022-01-20 11:37:04,425: INFO: deleting the raw counts dictionary of 30675 items
# 2022-01-20 11:37:04,428: INFO: sample=0.001 downsamples 55 most-common words
# 2022-01-20 11:37:04,430: INFO: downsampling leaves estimated 619881 word corpus (77.9% of prior 795574)
# 2022-01-20 11:37:04,462: INFO: estimated required memory for 9106 words and 100 dimensions: 11837800 bytes
# 2022-01-20 11:37:04,464: INFO: resetting layer weights
# 2022-01-20 11:37:06,381: INFO: training model with 3 workers on 9106 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=3
# 2022-01-20 11:37:07,352: INFO: worker thread finished; awaiting finish of 2 more threads
# 2022-01-20 11:37:07,359: INFO: worker thread finished; awaiting finish of 1 more threads
# 2022-01-20 11:37:07,367: INFO: worker thread finished; awaiting finish of 0 more threads
# 2022-01-20 11:37:07,371: INFO: EPOCH - 1 : training on 830015 raw words (620147 effective words) took 1.0s, 634914 effective words/s
# 2022-01-20 11:37:08,339: INFO: worker thread finished; awaiting finish of 2 more threads
# 2022-01-20 11:37:08,342: INFO: worker thread finished; awaiting finish of 1 more threads
# 2022-01-20 11:37:08,356: INFO: worker thread finished; awaiting finish of 0 more threads
# 2022-01-20 11:37:08,357: INFO: EPOCH - 2 : training on 830015 raw words (619584 effective words) took 1.0s, 640722 effective words/s
# 2022-01-20 11:37:09,322: INFO: worker thread finished; awaiting finish of 2 more threads
# 2022-01-20 11:37:09,324: INFO: worker thread finished; awaiting finish of 1 more threads
# 2022-01-20 11:37:09,339: INFO: worker thread finished; awaiting finish of 0 more threads
# 2022-01-20 11:37:09,341: INFO: EPOCH - 3 : training on 830015 raw words (620183 effective words) took 1.0s, 637450 effective words/s
# 2022-01-20 11:37:10,322: INFO: worker thread finished; awaiting finish of 2 more threads
# 2022-01-20 11:37:10,325: INFO: worker thread finished; awaiting finish of 1 more threads
# 2022-01-20 11:37:10,329: INFO: worker thread finished; awaiting finish of 0 more threads
# 2022-01-20 11:37:10,330: INFO: EPOCH - 4 : training on 830015 raw words (620021 effective words) took 1.0s, 634217 effective words/s
# 2022-01-20 11:37:11,309: INFO: worker thread finished; awaiting finish of 2 more threads
# 2022-01-20 11:37:11,320: INFO: worker thread finished; awaiting finish of 1 more threads
# 2022-01-20 11:37:11,329: INFO: worker thread finished; awaiting finish of 0 more threads
# 2022-01-20 11:37:11,332: INFO: EPOCH - 5 : training on 830015 raw words (619490 effective words) took 1.0s, 626409 effective words/s
# 2022-01-20 11:37:11,334: INFO: training on a 4150075 raw words (3099425 effective words) took 5.0s, 625925 effective words/s
# 2022-01-20 11:37:11,338: INFO: collecting all words and their counts
# 2022-01-20 11:37:11,339: INFO: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2022-01-20 11:37:11,364: INFO: PROGRESS: at sentence #10000, processed 79207 words, keeping 8710 word types
# 2022-01-20 11:37:11,389: INFO: PROGRESS: at sentence #20000, processed 156921 words, keeping 12509 word types
# 2022-01-20 11:37:11,409: INFO: PROGRESS: at sentence #30000, processed 230335 words, keeping 15538 word types
# 2022-01-20 11:37:11,431: INFO: PROGRESS: at sentence #40000, processed 306343 words, keeping 18757 word types
# 2022-01-20 11:37:11,453: INFO: PROGRESS: at sentence #50000, processed 381777 words, keeping 20753 word types
# 2022-01-20 11:37:11,493: INFO: PROGRESS: at sentence #60000, processed 455792 words, keeping 23041 word types
# 2022-01-20 11:37:11,517: INFO: PROGRESS: at sentence #70000, processed 535002 words, keeping 24926 word types
# ===>>Model : 3, Algo : w2v , Variant: sg, Window: 2, Size: 100
# ==========================================================================================
# 2022-01-20 11:37:11,543: INFO: PROGRESS: at sentence #80000, processed 610642 words, keeping 26451 word types
# 2022-01-20 11:37:11,568: INFO: PROGRESS: at sentence #90000, processed 687819 words, keeping 27905 word types
# 2022-01-20 11:37:11,592: INFO: PROGRESS: at sentence #100000, processed 763170 words, keeping 29478 word types
# 2022-01-20 11:37:11,612: INFO: collected 30675 word types from a corpus of 830015 raw words and 108774 sentences
# 2022-01-20 11:37:11,614: INFO: Loading a fresh vocabulary
# 2022-01-20 11:37:11,646: INFO: effective_min_count=5 retains 9106 unique words (29% of original 30675, drops 21569)
# 2022-01-20 11:37:11,655: INFO: effective_min_count=5 leaves 795574 word corpus (95% of original 830015, drops 34441)
# 2022-01-20 11:37:11,690: INFO: deleting the raw counts dictionary of 30675 items
# 2022-01-20 11:37:11,692: INFO: sample=0.001 downsamples 55 most-common words
# 2022-01-20 11:37:11,697: INFO: downsampling leaves estimated 619881 word corpus (77.9% of prior 795574)
# 2022-01-20 11:37:11,725: INFO: estimated required memory for 9106 words and 100 dimensions: 11837800 bytes
# 2022-01-20 11:37:11,733: INFO: resetting layer weights
# 2022-01-20 11:37:13,718: INFO: training model with 3 workers on 9106 vocabulary and 100 features, using sg=1 hs=0 sample=0.001 negative=5 window=2
# 2022-01-20 11:37:14,734: INFO: EPOCH 1 - PROGRESS: at 62.62% examples, 385101 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 11:37:15,239: INFO: worker thread finished; awaiting finish of 2 more threads
# 2022-01-20 11:37:15,269: INFO: worker thread finished; awaiting finish of 1 more threads
# 2022-01-20 11:37:15,276: INFO: worker thread finished; awaiting finish of 0 more threads
# 2022-01-20 11:37:15,277: INFO: EPOCH - 1 : training on 830015 raw words (619771 effective words) took 1.5s, 400190 effective words/s
# 2022-01-20 11:37:16,300: INFO: EPOCH 2 - PROGRESS: at 62.62% examples, 384954 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 11:37:16,822: INFO: worker thread finished; awaiting finish of 2 more threads
# 2022-01-20 11:37:16,834: INFO: worker thread finished; awaiting finish of 1 more threads
# 2022-01-20 11:37:16,859: INFO: worker thread finished; awaiting finish of 0 more threads
# 2022-01-20 11:37:16,860: INFO: EPOCH - 2 : training on 830015 raw words (620093 effective words) took 1.6s, 395808 effective words/s
# 2022-01-20 11:37:17,885: INFO: EPOCH 3 - PROGRESS: at 64.94% examples, 397917 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 11:37:18,369: INFO: worker thread finished; awaiting finish of 2 more threads
# 2022-01-20 11:37:18,394: INFO: worker thread finished; awaiting finish of 1 more threads
# 2022-01-20 11:37:18,398: INFO: worker thread finished; awaiting finish of 0 more threads
# 2022-01-20 11:37:18,400: INFO: EPOCH - 3 : training on 830015 raw words (619651 effective words) took 1.5s, 406193 effective words/s
# 2022-01-20 11:37:19,450: INFO: EPOCH 4 - PROGRESS: at 64.94% examples, 388148 words/s, in_qsize 6, out_qsize 2
# 2022-01-20 11:37:19,928: INFO: worker thread finished; awaiting finish of 2 more threads
# 2022-01-20 11:37:19,942: INFO: worker thread finished; awaiting finish of 1 more threads
# 2022-01-20 11:37:19,948: INFO: worker thread finished; awaiting finish of 0 more threads
# 2022-01-20 11:37:19,950: INFO: EPOCH - 4 : training on 830015 raw words (620375 effective words) took 1.5s, 403671 effective words/s
# 2022-01-20 11:37:20,980: INFO: EPOCH 5 - PROGRESS: at 64.94% examples, 393473 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 11:37:21,459: INFO: worker thread finished; awaiting finish of 2 more threads
# 2022-01-20 11:37:21,473: INFO: worker thread finished; awaiting finish of 1 more threads
# 2022-01-20 11:37:21,480: INFO: worker thread finished; awaiting finish of 0 more threads
# 2022-01-20 11:37:21,481: INFO: EPOCH - 5 : training on 830015 raw words (619547 effective words) took 1.5s, 406873 effective words/s
# 2022-01-20 11:37:21,485: INFO: training on a 4150075 raw words (3099437 effective words) took 7.8s, 399091 effective words/s
# 2022-01-20 11:37:21,491: INFO: collecting all words and their counts
# 2022-01-20 11:37:21,494: INFO: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2022-01-20 11:37:21,514: INFO: PROGRESS: at sentence #10000, processed 79207 words, keeping 8710 word types
# 2022-01-20 11:37:21,538: INFO: PROGRESS: at sentence #20000, processed 156921 words, keeping 12509 word types
# 2022-01-20 11:37:21,560: INFO: PROGRESS: at sentence #30000, processed 230335 words, keeping 15538 word types
# 2022-01-20 11:37:21,589: INFO: PROGRESS: at sentence #40000, processed 306343 words, keeping 18757 word types
# 2022-01-20 11:37:21,611: INFO: PROGRESS: at sentence #50000, processed 381777 words, keeping 20753 word types
# 2022-01-20 11:37:21,633: INFO: PROGRESS: at sentence #60000, processed 455792 words, keeping 23041 word types
# 2022-01-20 11:37:21,657: INFO: PROGRESS: at sentence #70000, processed 535002 words, keeping 24926 word types
# 2022-01-20 11:37:21,685: INFO: PROGRESS: at sentence #80000, processed 610642 words, keeping 26451 word types
# 2022-01-20 11:37:21,707: INFO: PROGRESS: at sentence #90000, processed 687819 words, keeping 27905 word types
# ===>>Model : 4, Algo : w2v , Variant: sg, Window: 3, Size: 100
# ==========================================================================================
# 2022-01-20 11:37:21,741: INFO: PROGRESS: at sentence #100000, processed 763170 words, keeping 29478 word types
# 2022-01-20 11:37:21,761: INFO: collected 30675 word types from a corpus of 830015 raw words and 108774 sentences
# 2022-01-20 11:37:21,763: INFO: Loading a fresh vocabulary
# 2022-01-20 11:37:21,797: INFO: effective_min_count=5 retains 9106 unique words (29% of original 30675, drops 21569)
# 2022-01-20 11:37:21,799: INFO: effective_min_count=5 leaves 795574 word corpus (95% of original 830015, drops 34441)
# 2022-01-20 11:37:21,832: INFO: deleting the raw counts dictionary of 30675 items
# 2022-01-20 11:37:21,834: INFO: sample=0.001 downsamples 55 most-common words
# 2022-01-20 11:37:21,835: INFO: downsampling leaves estimated 619881 word corpus (77.9% of prior 795574)
# 2022-01-20 11:37:21,869: INFO: estimated required memory for 9106 words and 100 dimensions: 11837800 bytes
# 2022-01-20 11:37:21,871: INFO: resetting layer weights
# 2022-01-20 11:37:23,809: INFO: training model with 3 workers on 9106 vocabulary and 100 features, using sg=1 hs=0 sample=0.001 negative=5 window=3
# 2022-01-20 11:37:24,852: INFO: EPOCH 1 - PROGRESS: at 55.61% examples, 333429 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 11:37:25,591: INFO: worker thread finished; awaiting finish of 2 more threads
# 2022-01-20 11:37:25,598: INFO: worker thread finished; awaiting finish of 1 more threads
# 2022-01-20 11:37:25,617: INFO: worker thread finished; awaiting finish of 0 more threads
# 2022-01-20 11:37:25,619: INFO: EPOCH - 1 : training on 830015 raw words (619856 effective words) took 1.8s, 345241 effective words/s
# 2022-01-20 11:37:26,641: INFO: EPOCH 2 - PROGRESS: at 54.41% examples, 332303 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 11:37:27,400: INFO: worker thread finished; awaiting finish of 2 more threads
# 2022-01-20 11:37:27,414: INFO: worker thread finished; awaiting finish of 1 more threads
# 2022-01-20 11:37:27,441: INFO: worker thread finished; awaiting finish of 0 more threads
# 2022-01-20 11:37:27,444: INFO: EPOCH - 2 : training on 830015 raw words (619932 effective words) took 1.8s, 341755 effective words/s
# 2022-01-20 11:37:28,484: INFO: EPOCH 3 - PROGRESS: at 55.61% examples, 333518 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 11:37:29,221: INFO: worker thread finished; awaiting finish of 2 more threads
# 2022-01-20 11:37:29,235: INFO: worker thread finished; awaiting finish of 1 more threads
# 2022-01-20 11:37:29,260: INFO: worker thread finished; awaiting finish of 0 more threads
# 2022-01-20 11:37:29,261: INFO: EPOCH - 3 : training on 830015 raw words (619899 effective words) took 1.8s, 343450 effective words/s
# 2022-01-20 11:37:30,292: INFO: EPOCH 4 - PROGRESS: at 55.61% examples, 340236 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 11:37:31,047: INFO: worker thread finished; awaiting finish of 2 more threads
# 2022-01-20 11:37:31,064: INFO: worker thread finished; awaiting finish of 1 more threads
# 2022-01-20 11:37:31,073: INFO: worker thread finished; awaiting finish of 0 more threads
# 2022-01-20 11:37:31,074: INFO: EPOCH - 4 : training on 830015 raw words (620320 effective words) took 1.8s, 346185 effective words/s
# 2022-01-20 11:37:32,118: INFO: EPOCH 5 - PROGRESS: at 55.61% examples, 333674 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 11:37:32,846: INFO: worker thread finished; awaiting finish of 2 more threads
# 2022-01-20 11:37:32,863: INFO: worker thread finished; awaiting finish of 1 more threads
# 2022-01-20 11:37:32,883: INFO: worker thread finished; awaiting finish of 0 more threads
# 2022-01-20 11:37:32,885: INFO: EPOCH - 5 : training on 830015 raw words (619826 effective words) took 1.8s, 345225 effective words/s
# 2022-01-20 11:37:32,886: INFO: training on a 4150075 raw words (3099833 effective words) took 9.1s, 341568 effective words/s
# 2022-01-20 11:37:32,888: INFO: collecting all words and their counts
# 2022-01-20 11:37:32,890: INFO: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2022-01-20 11:37:32,919: INFO: PROGRESS: at sentence #10000, processed 79207 words, keeping 8710 word types
# 2022-01-20 11:37:32,945: INFO: PROGRESS: at sentence #20000, processed 156921 words, keeping 12509 word types
# 2022-01-20 11:37:32,973: INFO: PROGRESS: at sentence #30000, processed 230335 words, keeping 15538 word types
# 2022-01-20 11:37:32,997: INFO: PROGRESS: at sentence #40000, processed 306343 words, keeping 18757 word types
# 2022-01-20 11:37:33,023: INFO: PROGRESS: at sentence #50000, processed 381777 words, keeping 20753 word types
# 2022-01-20 11:37:33,045: INFO: PROGRESS: at sentence #60000, processed 455792 words, keeping 23041 word types
# 2022-01-20 11:37:33,066: INFO: PROGRESS: at sentence #70000, processed 535002 words, keeping 24926 word types
# 2022-01-20 11:37:33,090: INFO: PROGRESS: at sentence #80000, processed 610642 words, keeping 26451 word types
# ===>>Model : 5, Algo : ft , Variant: sg, Window: 5, Size: 100
# ==========================================================================================
# 2022-01-20 11:37:33,117: INFO: PROGRESS: at sentence #90000, processed 687819 words, keeping 27905 word types
# 2022-01-20 11:37:33,137: INFO: PROGRESS: at sentence #100000, processed 763170 words, keeping 29478 word types
# 2022-01-20 11:37:33,162: INFO: collected 30675 word types from a corpus of 830015 raw words and 108774 sentences
# 2022-01-20 11:37:33,165: INFO: Loading a fresh vocabulary
# 2022-01-20 11:37:33,200: INFO: effective_min_count=5 retains 9106 unique words (29% of original 30675, drops 21569)
# 2022-01-20 11:37:33,204: INFO: effective_min_count=5 leaves 795574 word corpus (95% of original 830015, drops 34441)
# 2022-01-20 11:37:33,243: INFO: deleting the raw counts dictionary of 30675 items
# 2022-01-20 11:37:33,245: INFO: sample=0.001 downsamples 55 most-common words
# 2022-01-20 11:37:33,249: INFO: downsampling leaves estimated 619881 word corpus (77.9% of prior 795574)
# 2022-01-20 11:37:33,384: INFO: estimated required memory for 9106 words, 63081 buckets and 100 dimensions: 38897880 bytes
# 2022-01-20 11:37:33,387: INFO: resetting layer weights
# 2022-01-20 11:37:35,708: INFO: Total number of ngrams is 63081
# 2022-01-20 11:37:36,186: INFO: training model with 3 workers on 9106 vocabulary and 100 features, using sg=1 hs=0 sample=0.001 negative=5 window=5
# 2022-01-20 11:37:37,227: INFO: EPOCH 1 - PROGRESS: at 26.28% examples, 159398 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 11:37:38,268: INFO: EPOCH 1 - PROGRESS: at 55.61% examples, 165685 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 11:37:39,289: INFO: EPOCH 1 - PROGRESS: at 82.99% examples, 166575 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 11:37:39,758: INFO: worker thread finished; awaiting finish of 2 more threads
# 2022-01-20 11:37:39,818: INFO: worker thread finished; awaiting finish of 1 more threads
# 2022-01-20 11:37:39,822: INFO: worker thread finished; awaiting finish of 0 more threads
# 2022-01-20 11:37:39,824: INFO: EPOCH - 1 : training on 830015 raw words (620007 effective words) took 3.6s, 170913 effective words/s
# 2022-01-20 11:37:40,859: INFO: EPOCH 2 - PROGRESS: at 26.28% examples, 161447 words/s, in_qsize 6, out_qsize 0
# 2022-01-20 11:37:41,874: INFO: EPOCH 2 - PROGRESS: at 54.43% examples, 165192 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 11:37:42,894: INFO: EPOCH 2 - PROGRESS: at 82.99% examples, 168632 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 11:37:43,439: INFO: worker thread finished; awaiting finish of 2 more threads
# 2022-01-20 11:37:43,482: INFO: worker thread finished; awaiting finish of 1 more threads
# 2022-01-20 11:37:43,495: INFO: worker thread finished; awaiting finish of 0 more threads
# 2022-01-20 11:37:43,497: INFO: EPOCH - 2 : training on 830015 raw words (619659 effective words) took 3.7s, 169453 effective words/s
# 2022-01-20 11:37:44,533: INFO: EPOCH 3 - PROGRESS: at 25.00% examples, 153826 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 11:37:45,575: INFO: EPOCH 3 - PROGRESS: at 54.43% examples, 162853 words/s, in_qsize 4, out_qsize 1
# 2022-01-20 11:37:46,640: INFO: EPOCH 3 - PROGRESS: at 84.22% examples, 167194 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 11:37:47,100: INFO: worker thread finished; awaiting finish of 2 more threads
# 2022-01-20 11:37:47,121: INFO: worker thread finished; awaiting finish of 1 more threads
# 2022-01-20 11:37:47,126: INFO: worker thread finished; awaiting finish of 0 more threads
# 2022-01-20 11:37:47,128: INFO: EPOCH - 3 : training on 830015 raw words (620427 effective words) took 3.6s, 171578 effective words/s
# 2022-01-20 11:37:48,176: INFO: EPOCH 4 - PROGRESS: at 26.28% examples, 158951 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 11:37:49,205: INFO: EPOCH 4 - PROGRESS: at 55.61% examples, 166406 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 11:37:50,207: INFO: EPOCH 4 - PROGRESS: at 82.99% examples, 168090 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 11:37:50,733: INFO: worker thread finished; awaiting finish of 2 more threads
# 2022-01-20 11:37:50,764: INFO: worker thread finished; awaiting finish of 1 more threads
# 2022-01-20 11:37:50,777: INFO: worker thread finished; awaiting finish of 0 more threads
# 2022-01-20 11:37:50,779: INFO: EPOCH - 4 : training on 830015 raw words (620057 effective words) took 3.6s, 170431 effective words/s
# 2022-01-20 11:37:51,868: INFO: EPOCH 5 - PROGRESS: at 27.53% examples, 162158 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 11:37:52,927: INFO: EPOCH 5 - PROGRESS: at 56.78% examples, 165367 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 11:37:53,956: INFO: EPOCH 5 - PROGRESS: at 85.47% examples, 168373 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 11:37:54,409: INFO: worker thread finished; awaiting finish of 2 more threads
# 2022-01-20 11:37:54,411: INFO: worker thread finished; awaiting finish of 1 more threads
# 2022-01-20 11:37:54,435: INFO: worker thread finished; awaiting finish of 0 more threads
# 2022-01-20 11:37:54,437: INFO: EPOCH - 5 : training on 830015 raw words (620275 effective words) took 3.6s, 170870 effective words/s
# 2022-01-20 11:37:54,438: INFO: training on a 4150075 raw words (3100425 effective words) took 18.3s, 169885 effective words/s
# ===>>Model : 6, Algo : cust , Variant: sg, Window: 2, Size: 100
# ==========================================================================================

# %% [markdown]
# ##**Compare Word2Vec, FastText and Custom model**

# %%
import pandas as pd

def compare_models(models, **kwargs):
    index=0
    df = pd.DataFrame()
    for m in models:
        index+=1
        name= ("Model : " + str(index) )
        df[name] = [f"{word} {score:.3f}"
                    for word, score in model.wv.most_similar(**kwargs)]
    df.index = df.index + 1 # let row index start at 1
    return df

# %%
compare_models(models, positive='king', topn=10)
# Out:
#          Model : 1       Model : 2  ...       Model : 5       Model : 6
# 1       duke 0.862      duke 0.862  ...      duke 0.862      duke 0.862
# 2      queen 0.809     queen 0.809  ...     queen 0.809     queen 0.809
# 3     prince 0.794    prince 0.794  ...    prince 0.794    prince 0.794
# 4     doctor 0.788    doctor 0.788  ...    doctor 0.788    doctor 0.788
# 5       Moor 0.787      Moor 0.787  ...      Moor 0.787      Moor 0.787
# 6        Jew 0.773       Jew 0.773  ...       Jew 0.773       Jew 0.773
# 7     Caesar 0.767    Caesar 0.767  ...    Caesar 0.767    Caesar 0.767
# 8   cardinal 0.762  cardinal 0.762  ...  cardinal 0.762  cardinal 0.762
# 9   shepherd 0.761  shepherd 0.761  ...  shepherd 0.761  shepherd 0.761
# 10   emperor 0.756   emperor 0.756  ...   emperor 0.756   emperor 0.756
#
# [10 rows x 6 columns]

# %%
# !pip3 install umap-learn
# Out:
# Requirement already satisfied: umap-learn in /usr/local/lib/python3.7/dist-packages (0.5.2)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.7/dist-packages (from umap-learn) (1.0.2)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.7/dist-packages (from umap-learn) (1.4.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from umap-learn) (4.62.3)
# Requirement already satisfied: numba>=0.49 in /usr/local/lib/python3.7/dist-packages (from umap-learn) (0.51.2)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.7/dist-packages (from umap-learn) (0.5.5)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from umap-learn) (1.19.5)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba>=0.49->umap-learn) (0.34.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba>=0.49->umap-learn) (57.4.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from pynndescent>=0.5->umap-learn) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.22->umap-learn) (3.0.0)

# %%
from umap import UMAP

model =cust_model
words = model.wv.vocab
wv = [model[word] for word in words]

reducer = UMAP(n_components=2, metric='cosine', n_neighbors = 15, min_dist=0.1, random_state = 12)
reduced_wv = reducer.fit_transform(wv)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# /usr/local/lib/python3.7/dist-packages/numba/np/ufunc/parallel.py:363: NumbaWarning: The TBB threading layer requires TBB version 2019.5 or later i.e., TBB_INTERFACE_VERSION >= 11005. Found TBB_INTERFACE_VERSION = 9107. The TBB threading layer is disabled.
#   warnings.warn(problem)

# %%
# !pip install plotly==4.8.2
# Out:
# Requirement already satisfied: plotly==4.8.2 in /usr/local/lib/python3.7/dist-packages (4.8.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from plotly==4.8.2) (1.15.0)
# Requirement already satisfied: retrying>=1.3.3 in /usr/local/lib/python3.7/dist-packages (from plotly==4.8.2) (1.3.3)

# %%
import plotly.express as px


px.defaults.template = "plotly_white" ### plotly style

plot_df = pd.DataFrame.from_records(reduced_wv, columns=['x', 'y'])
plot_df['word'] = words
params = {'hover_data': {c: False for c in plot_df.columns}, 
          'hover_name': 'word'}
params.update({'width': 800, 'height': 600}) ###


fig = px.scatter(plot_df, x="x", y="y", opacity=0.3, size_max=3, **params)
fig.update_traces(marker={'line': {'width': 0}}) ###
fig.update_xaxes(showticklabels=False, showgrid=True, zeroline=False, visible=True) ###
fig.update_yaxes(showticklabels=False, showgrid=True, zeroline=False, visible=True) ###

fig.update_layout(
    autosize=False,
    width=1000,
    height=1000,
    yaxis=dict(
        title_text="",
        ticktext=["Very long label", "long label", "3", "label"],
        tickvals=[1, 2, 3, 4],
        tickmode="array",
        titlefont=dict(size=50)))

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="8a526f5c-c413-4140-9208-22940dc2d697" class="plotly-graph-div" style="height:1000px; width:1000px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8a526f5c-c413-4140-9208-22940dc2d697")) {
#                     Plotly.newPlot(
#                         '8a526f5c-c413-4140-9208-22940dc2d697',
#                         [{"customdata": [[3.5697858333587646, -5.338064193725586, "ACT"], [-2.1448330879211426, 1.458378553390503, "I"], [3.608328104019165, -5.374576091766357, "SCENE"], [3.4226455688476562, -5.076547622680664, "London"], [3.575758218765259, -5.243298053741455, "The"], [3.461169481277466, -5.236290454864502, "palace"], [7.444587230682373, -7.927524566650391, "Enter"], [7.551145553588867, -7.714123249053955, "KING"], [7.561328887939453, -7.7880635261535645, "HENRY"], [7.242649078369141, -7.822611331939697, "LORD"], [7.514078617095947, -7.766525745391846, "JOHN"], [7.608519077301025, -7.828945636749268, "OF"], [7.277256965637207, -7.7617645263671875, "LANCASTER"], [3.3030049800872803, -1.6462867259979248, "the"], [7.233517169952393, -8.033326148986816, "EARL"], [0.9788177609443665, 2.5771641731262207, "of"], [6.696519374847412, -7.795036315917969, "WESTMORELAND"], [7.522740364074707, -8.014829635620117, "SIR"], [6.524686813354492, -8.154239654541016, "WALTER"], [6.715023517608643, -8.215300559997559, "BLUNT"], [1.8623861074447632, -4.794325351715088, "and"], [6.564547061920166, -7.5642924308776855, "others"], [-2.4719133377075195, -0.005732132121920586, "So"], [-2.4068143367767334, -0.05336122587323189, "as"], [-2.1027116775512695, 1.5912493467330933, "we"], [-3.193089246749878, 0.6801214218139648, "are"], [-2.4079957008361816, -0.02565954625606537, "so"], [0.5455941557884216, 2.2407162189483643, "with"], [-1.657173752784729, 1.92689847946167, "care"], [1.650484323501587, -1.5024350881576538, "Find"], [0.8316108584403992, -0.5665391683578491, "a"], [2.379228353500366, -0.15537509322166443, "time"], [-2.0397064685821533, 1.341437816619873, "for"], [-0.44290319085121155, -0.08565960824489594, "frighted"], [2.4750165939331055, 0.600251317024231, "peace"], [-2.1739661693573, 1.5558139085769653, "to"], [-2.2184178829193115, 0.9815331101417542, "And"], [-1.0111395120620728, 2.457266092300415, "breathe"], [1.2204571962356567, -3.965150833129883, "accents"], [2.5273561477661133, -1.4552013874053955, "new"], [1.4646841287612915, -4.595810413360596, "broils"], [-2.7709853649139404, 1.8723044395446777, "To"], [-1.3183414936065674, 2.44193434715271, "be"], [0.7018244862556458, 2.465575933456421, "in"], [5.529492378234863, -7.111822128295898, "afar"], [0.834054172039032, -4.820807456970215, "remote"], [0.7252503037452698, -0.06209088861942291, "No"], [0.9057337641716003, 0.09535995125770569, "more"], [0.5675344467163086, -2.6674046516418457, "thirsty"], [3.017979621887207, -1.0142498016357422, "entrance"], [0.9001597762107849, -0.4618794918060303, "this"], [2.6039276123046875, 0.07879354804754257, "soil"], [-2.8165628910064697, 1.9076485633850098, "Shall"], [2.984421491622925, 1.7444456815719604, "her"], [3.888162851333618, -0.4516383111476898, "lips"], [3.002004384994507, 0.6386887431144714, "own"], [4.030579090118408, -0.4589096009731293, "children"], [-3.628566265106201, 0.21110263466835022, "s"], [2.934152603149414, 0.11913633346557617, "blood"], [-1.849739670753479, 1.3342775106430054, "Nor"], [-2.867851734161377, 1.9764213562011719, "shall"], [2.6810290813446045, -0.6537535786628723, "war"], [0.9800206422805786, -2.3451895713806152, "channel"], [3.755014419555664, -1.4060863256454468, "fields"], [0.252488374710083, -3.79708194732666, "bruise"], [5.778284549713135, -7.294635772705078, "armed"], [0.9977132678031921, 2.591174364089966, "Of"], [1.0817561149597168, -4.709099292755127, "hostile"], [2.1060030460357666, -4.776365756988525, "paces"], [1.2598578929901123, 0.600202202796936, "those"], [1.6291786432266235, -0.8551235198974609, "opposed"], [4.06477165222168, -0.5412929654121399, "eyes"], [-2.074155807495117, 0.8323886394500732, "Which"], [-1.507546067237854, -0.18589428067207336, "like"], [-0.2085992395877838, -2.253445625305176, "meteors"], [-1.425966739654541, -0.5009043216705322, "troubled"], [-2.3905513286590576, -1.132874608039856, "heaven"], [1.2520369291305542, 0.47047924995422363, "All"], [1.157748341560363 ...
